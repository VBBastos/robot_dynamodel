# %% [markdown]
# # Mobile Robot (Syndi - Matlab)

# %% [markdown]
# ### created by Vinicius, 16/07/2019

# %% [markdown]
# ##### Import modules

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from pySINDy.sindy import SINDy
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

# %% [markdown]
# ##### Load data created by Matlab

# %%
mat = scipy.io.loadmat('data.mat')
datau = mat.get('ures')
dataw = mat.get('wres')
datauref = mat.get('urefres')
datawref = mat.get( 'wrefres')

# %%
data_total=np.concatenate((datau, dataw,datauref, datawref))

# %%
np.shape(data_total)
# Out:
# (4, 751)

# %%
model1 = SINDy(name='my_test_model1')

# %%
dt = 0.1
model1.fit(data_total, dt, poly_degree=3, cut_off=0.5)

# %%
model1.descriptions
# Out:
# ['1',
#  'u3',
#  'u1',
#  'u2',
#  'u0',
#  'u0^{2}',
#  'u1u3',
#  'u2^{2}',
#  'u2u3',
#  'u1u2',
#  'u0u2',
#  'u0u3',
#  'u3^{2}',
#  'u1^{2}',
#  'u0u1',
#  'u1u3^{2}',
#  'u0u2u3',
#  'u0u3^{2}',
#  'u1^{2}u3',
#  'u0u1u3',
#  'u2^{2}u3',
#  'u1u2u3',
#  'u0u2^{2}',
#  'u2^{3}',
#  'u1u2^{2}',
#  'u2u3^{2}',
#  'u1^{2}u2',
#  'u0u1u2',
#  'u0^{2}u2',
#  'u1^{3}',
#  'u0u1^{2}',
#  'u0^{2}u1',
#  'u0^{3}',
#  'u0^{2}u3',
#  'u3^{3}']

# %%
model1.plot_coefficients

# %%
model1.coefficients
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [ 4.80445013e+00, -5.97444298e+00,  2.94588931e+00,
#          2.03827289e+00],
#        [-2.04535345e+00,  2.25609735e+00, -1.30863107e+00,
#         -1.14886866e+00],
#        [ 9.42220906e+00, -2.19402346e+01,  6.23722492e+00,
#          0.00000000e+00],
#        [-5.42012518e+00,  8.73482043e+00, -2.75708590e+00,
#          0.00000000e+00],
#        [ 6.84487482e+01, -3.53730454e+01, -5.78519082e+00,
#          5.74018281e+00],
#        [-1.16884991e+01,  4.73472422e+01,  8.60653103e+00,
#          1.12857014e+01],
#        [ 2.76252747e+02,  2.07745331e+02, -9.12030473e+01,
#          2.81838521e+01],
#        [-5.42055992e+01,  1.13585844e+02, -6.78155960e+01,
#         -4.46542909e+01],
#        [ 3.13027625e+01, -7.92589785e+01,  3.78746178e+01,
#          2.22020955e+01],
#        [-3.01979417e+02,  5.13239692e+01,  4.84369357e+01,
#         -2.58685828e+01],
#        [ 2.55429665e+01, -4.98957900e+01,  1.83075815e+01,
#          8.76955767e+00],
#        [ 1.04584162e+01, -3.28279400e+01, -4.31845654e+00,
#         -7.31226903e+00],
#        [ 4.60550612e+00, -1.65062878e+01, -2.78777087e+00,
#         -4.06777453e+00],
#        [-1.24771570e+01,  3.06756980e+01, -1.05429930e+01,
#         -4.86938473e+00],
#        [ 7.28754613e+02, -1.72120112e+03,  9.41941916e+02,
#          8.34828385e+02],
#        [ 1.04453766e+04, -3.45217708e+03,  6.73383023e+02,
#          2.41084740e+03],
#        [ 5.57235133e+02,  7.18724001e+02,  6.60445711e+02,
#         -2.71440218e+02],
#        [-3.10850690e+02,  9.32974180e+02, -3.95031019e+02,
#         -3.57929570e+02],
#        [ 4.62834447e+02, -1.97964718e+03, -1.47701037e+02,
#          3.57681483e+02],
#        [-1.11729757e+04,  1.36287456e+03,  1.05390505e+03,
#         -9.49594648e+02],
#        [ 5.46167123e+02,  1.28013362e+03,  1.32954297e+02,
#         -1.27758135e+03],
#        [ 2.08106815e+04, -2.03641827e+04,  3.90730595e+03,
#          2.72058461e+03],
#        [-1.40155129e+03,  1.00542960e+04, -6.46107251e+02,
#         -1.53742681e+02],
#        [ 1.91821363e+03,  1.63476238e+04, -1.95921846e+03,
#         -1.00694220e+03],
#        [-2.43781673e+03,  1.00080752e+03, -1.44417440e+03,
#          8.37173033e+02],
#        [-2.02236125e+02,  2.60502865e+02,  4.11189531e+01,
#          4.85388389e+02],
#        [-2.84857508e+03, -1.02668423e+04,  6.86979302e+02,
#         -9.50498987e+01],
#        [-1.34266873e+04,  9.64904624e+03, -2.53478187e+03,
#         -1.88846547e+03],
#        [ 8.30594145e+01, -2.16623460e+02,  7.33925958e+01,
#          6.83542680e+01],
#        [-8.21544311e+01,  3.18621310e+02,  1.93085384e+01,
#         -1.37339428e+02],
#        [ 8.87082554e+02,  1.50172871e+03,  4.80690852e+01,
#          2.07357423e+02],
#        [ 2.29395342e+03, -1.38475690e+03,  4.54573893e+02,
#          3.39878653e+02],
#        [-2.56745943e+03,  1.27117038e+03, -4.69956551e+02,
#         -8.17433111e+02],
#        [-1.01500001e+03,  1.66795818e+03, -9.55626003e+02,
#         -7.24441702e+02]])
